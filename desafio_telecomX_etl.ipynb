# %%
# ETL - Desafio Telecom X
# Versão inicial do notebook

# 🧰 Bibliotecas principais
import pandas as pd
import numpy as np
import requests

# Desabilita avisos desnecessários
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# URL correta do arquivo JSON
url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/main/TelecomX_Data.json"

# Lê o arquivo JSON diretamente da internet
df = pd.read_json(url)

# Mostra as primeiras linhas da tabela
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-3617111529.py in <cell line: 0>()
# ----> 1 df.drop_duplicates(inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6956         else:
#    6957             vals = (col.values for name, col in self.items() if name in subset)
# -> 6958             labels, shape = map(list, zip(*map(f, vals)))
#    6959
# ...

# %%
# Separar os dados das colunas que contêm dicionários

# Expandir a coluna 'customer'
customer_df = pd.json_normalize(df['customer'])
phone_df = pd.json_normalize(df['phone'])
internet_df = pd.json_normalize(df['internet'])
account_df = pd.json_normalize(df['account'])

# Juntar tudo em um novo DataFrame completo
df_final = pd.concat([df[['customerID', 'Churn']], customer_df, phone_df, internet_df, account_df], axis=1)

# Visualizar os dados tratados
df_final.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_final.drop_duplicates(inplace=True)

# %%
df_final.columns = [col.lower().strip().replace(" ", "_") for col in df_final.columns]

# %%
df_final.to_csv("dados_tratados.csv", index=False)

# %%
df_final.to_csv("dados_tratados.csv", index=False)

# %% [markdown]
# # Relatório – Processo de ETL | Desafio Telecom X
#
# ## Introdução
#
# O presente relatório descreve o processo de ETL (Extração, Transformação e Carga) realizado sobre os dados da empresa fictícia Telecom X, fornecidos em formato JSON. O objetivo principal foi preparar os dados para análises futuras que possam apoiar a equipe de Data Science na redução da taxa de evasão de clientes (churn), um dos maiores desafios enfrentados atualmente pela empresa.
#
# ## 1. Extração dos Dados
#
# A extração foi realizada a partir do seguinte endereço hospedado no GitHub:
#
# https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/main/TelecomX_Data.json
#
# Utilizou-se a biblioteca pandas para leitura do arquivo JSON:
#
# ```python
# import pandas as pd
# url = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/main/TelecomX_Data.json"
# df = pd.read_json(url)

# %%
df_final.to_csv("dados_tratados.csv", index=False)
